# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import Adam

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using {device} device')
# Out:
# Using cuda device

# %%
# 데이터 로딩
path = 'https://bit.ly/ds_boston_csv'
data = pd.read_csv(path)


# x, y 분할
target = 'medv'
features = ['lstat', 'ptratio', 'crim']  #3개만 가져오기
x = data.loc[:, features]
y = data.loc[:, target]


# train, val 분할
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)


# 스케일러 선언
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %%
# 데이터 로더 함수
def make_DataSet(x_train, x_val, y_train, y_val, batch_size = 32) :
    # 데이터 텐서로 변환
    x_train_tensor = torch.tensor(x_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
    x_val_tensor = torch.tensor(x_val, dtype=torch.float32)
    y_val_tensor = torch.tensor(y_val, dtype=torch.float32).view(-1, 1)


    # TensorDataset 생성: 텐서 데이터 세트로 합치기
    train_dataset = TensorDataset(x_train_tensor, y_train_tensor) #학습데이터셋을 만듬


    # DataLoader 생성
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle = True)


    return train_loader, x_val_tensor, y_val_tensor

# %%
# 데이터프레임을 넘파이 배열로 변환
print(type(y_train), type(y_val))
y_train = y_train.values
y_val = y_val.values
print(type(y_train), type(y_val))
# Out:
# <class 'pandas.Series'> <class 'pandas.Series'>
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
# make_DataSet 함수로 데이터 로더를 구성
train_loader, x_val_ts, y_val_ts = make_DataSet(x_train, x_val, y_train, y_val, 32)


# 첫 번째 배치만 로딩해서 살펴보기
for x, y in train_loader:
    print(f'Shape of x [rows, columns]: {x.shape}')
    print(f'Shape of y: {y.shape} {y.dtype}')
    break    #어떤 데이터가 들어가는지 확인만 하는용도 ->  [32,3] 이 들어가고 [32,1] 나옴   
#batch_size = 32이기때문에 32가 나옴
# Out:
# Shape of x [rows, columns]: torch.Size([32, 3])
# Shape of y: torch.Size([32, 1]) torch.float32

# %%
n_feature = x.shape[1]
model1 = nn.Sequential(nn.Linear(n_feature, 1)).to(device)


loss_fn = nn.MSELoss()
optimizer = Adam(model1.parameters(), lr=0.01)
print(model1)
# Out:
# Sequential(
#   (0): Linear(in_features=3, out_features=1, bias=True)
# )

# %%
#train 함수
def train(dataloader, model, loss_fn, optimizer, device):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    tr_loss = 0
    model.train()
    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        pred = model(x)
        loss = loss_fn(pred, y)
        tr_loss += loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    tr_loss /= num_batches
    return tr_loss.item()

# %%
#평가 함수
def evaluate(x_val_tensor, y_val_tensor, model, loss_fn, device):
    model.eval()   #반드시 이발모드로 바꿔줘야함
    with torch.no_grad():  #no grad를 하면 학습안해도됨  -> 왜냐하면 이건 평가함수이기 때문에
        x, y = x_val_tensor.to(device), y_val_tensor.to(device)
        pred = model(x)
        val_loss = loss_fn(pred, y).item()
    return val_loss, pred

# %%
#200번 cuda 돌아가게 함epochs = 200
epochs = 200
tr_loss_list, val_loss_list = [], []
for t in range(epochs):
    tr_loss = train(train_loader, model1, loss_fn, optimizer, device)
    val_loss, _ = evaluate(x_val_ts, y_val_ts, model1, loss_fn, device)
    tr_loss_list.append(tr_loss)
    val_loss_list.append(val_loss)
# Epoch 161, train loss: 66.998512, val loss: 52.637344
# Epoch 162, train loss: 66.364029, val loss: 52.546528
# Epoch 163, train loss: 67.571686, val loss: 52.406731
# Epoch 164, train loss: 64.987465, val loss: 52.286518
# Epoch 165, train loss: 66.035431, val loss: 52.147366
# Epoch 166, train loss: 65.631836, val loss: 52.022411
# Epoch 167, train loss: 63.953846, val loss: 51.890652
# Epoch 168, train loss: 64.628983, val loss: 51.754742
# Epoch 169, train loss: 63.347626, val loss: 51.618500
# Epoch 170, train loss: 65.381546, val loss: 51.514889
# Epoch 171, train loss: 63.361393, val loss: 51.390541
# Epoch 172, train loss: 63.001492, val loss: 51.260303
# Epoch 173, train loss: 62.661961, val loss: 51.151432
# Epoch 174, train loss: 63.524178, val loss: 51.029793
# Epoch 175, train loss: 65.104378, val loss: 50.902500
# Epoch 176, train loss: 63.692986, val loss: 50.771622
# Epoch 177, train loss: 61.918716, val loss: 50.657967
# Epoch 178, train loss: 65.150124, val loss: 50.530842
# Epoch 179, train loss: 63.029472, val loss: 50.427639
# Epoch 180, train loss: 62.352470, val loss: 50.309959
# Epoch 181, train loss: 61.579288, val loss: 50.176720
# Epoch 182, train loss: 63.565723, val loss: 50.059074
# Epoch 183, train loss: 62.331230, val loss: 49.970524
# Epoch 184, train loss: 61.117836, val loss: 49.840706
# Epoch 185, train loss: 61.282421, val loss: 49.707996
# Epoch 186, train loss: 60.504139, val loss: 49.597794
# Epoch 187, train loss: 61.398598, val loss: 49.473251
# Epoch 188, train loss: 60.912949, val loss: 49.364067
# Epoch 189, train loss: 59.675755, val loss: 49.246723
# Epoch 190, train loss: 61.113007, val loss: 49.126984
# Epoch 191, train loss: 60.229031, val loss: 49.007576
# Epoch 192, train loss: 60.629196, val loss: 48.886547
# Epoch 193, train loss: 58.931797, val loss: 48.795029
# Epoch 194, train loss: 60.886276, val loss: 48.671143
# Epoch 195, train loss: 60.700096, val loss: 48.548740
# Epoch 196, train loss: 58.441006, val loss: 48.483547
# Epoch 197, train loss: 59.411423, val loss: 48.354671
# Epoch 198, train loss: 58.688999, val loss: 48.228413
# Epoch 199, train loss: 58.004997, val loss: 48.125317
# Epoch 200, train loss: 59.455212, val loss: 48.003246

# %%
# 학습곡선 함수   - 학습 확인할 수 있는 함수
def dl_learning_curve(tr_loss_list, val_loss_list):
    epochs = list(range(1, len(tr_loss_list)+1))
    plt.plot(epochs, tr_loss_list, label='train_err', marker = '.')
    plt.plot(epochs, val_loss_list, label='val_err', marker = '.')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %%
  # 학습 곡선
dl_learning_curve(tr_loss_list, val_loss_list)

# %%
_, pred = evaluate(x_val_ts, y_val_ts, model1, loss_fn, device)
mae = mean_absolute_error(y_val_ts.cpu().numpy(), pred.cpu().numpy())
mape = mean_absolute_percentage_error(y_val_ts.cpu().numpy(), pred.cpu().numpy())
print(f'MAE : {mae}')
print(f'MAPE : {mape}')
# Out:
# MAE : 4.928329944610596
# MAPE : 0.23889099061489105
